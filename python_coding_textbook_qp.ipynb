# %%
# Python Program to add two numbers.
a = b = 10
print("Sum =",(a+b))
# Out:
# Sum = 20

# %%
# Program two add two numbers.
a = 10
b = 15
c = a + b
print("sum =",c)
# Out:
# sum = 25

# %%
# Program with two functions
def add(x, y):
    """
    This function takes two numbers and finds their sum.
    It displays the sum as result.
    """
    print("Sum =", (x+y))

def message():
    ''' 
    This function displays a message.
    This is a welcome message to the user.
    '''
    print("Welcome to Python")

# now call the function
add(10, 15)
message()
# Out:
# Sum = 25
# Welcome to Python

# %%
# Python program to add two complex numbers
c1 = 2.5+2.5j
c2 = 3.0-0.5j
c3 = c1 + c2
print("Sum =", c3)
# Out:
# Sum = (5.5+2j)

# %%
# converting the datatype of a given value.
x = 15.56
num = 15
y = 10
print(int(x))
print(float(num))
print(complex(y))
# Out:
# 15
# 15.0
# (10+0j)

# %%
# A Program to convert numbers from octal, binary and hexadecimal systems into decimal number system.
n1 = 0o17
n2 = 0B1110010
n3 = 0x1c2

n = int(n1)
print("Octal 17 = ", n)
n = int(n2)
print("Binary 1110010 = ", n)
n = int(n3)
print("Hexadecimal 1c2 = ", n)
# Out:
# Octal 17 =  15
# Binary 1110010 =  114
# Hexadecimal 1c2 =  450

# %%
# A Python Program to convert into decimal number system.
s1 = "17"
s2 = "1110010"
s3 = "1c2"

n = int(s1, 8)
print("Octal 17 =", n)
n = int(s2, 2)
print("Binary 1110010 =", n)
n = int(s3, 16)
print("Hexadecimal 1c2 =", n)
# Out:
# Octal 17 = 15
# Binary 1110010 = 114
# Hexadecimal 1c2 = 450

# %%
# Python Program to convert numbers into bin, oct, hex
a = 10
b = bin(a)
print(b)

b = oct(a)
print(b)

b = hex(a)
print(b)
# Out:
# 0b1010
# 0o12
# 0xa

# %%
# Bool datatype
a = 10
b = 20
if (a<b):
    print("Hello")
# Out:
# Hello

# %%
a = 10 > 5
print(a)
# Out:
# True

# %%
a = 5 > 10
print(a)
# Out:
# False

# %%
# A Python Program to create a byte type array
elements = [10, 20, 0, 40, 15]

# converts the list into bytes type array
x = bytes(elements)
for i in x:
    print(i)
# Out:
# 10
# 20
# 0
# 40
# 15

# %%
# A Python Program to create a bytearray type array and retrieve elements
# Page no. 58
